# %%
import pandas as pd
import calendar
import json
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/amishra/DEV/DataEngineering.Labs.AirflowProject/DataEngg-Airflow/youtube-new/USvideos.csv')
df['month'] = df.apply(lambda row: calendar.month_name[int(row.trending_date.split(".")[2])], axis=1)
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
#df1 = pd.read_json('/Users/amishra/DEV/DataEngineering.Labs.AirflowProject/DataEngg-Airflow/youtube-new/US_category_id.json')
#df1.items

data = None
with open('/Users/amishra/DEV/DataEngineering.Labs.AirflowProject/DataEngg-Airflow/youtube-new/US_category_id.json') as f:
    data = json.load(f)

category_list = list()
for c in data['items']:
    category_list.append([c['id'],c['snippet']['title']])

df11 = pd.DataFrame(category_list, columns = ['category_id', 'category_title'])
df11
# Out:
#    category_id         category_title
# 0            1       Film & Animation
# 1            2       Autos & Vehicles
# 2           10                  Music
# 3           15         Pets & Animals
# 4           17                 Sports
# 5           18           Short Movies
# 6           19        Travel & Events
# 7           20                 Gaming
# 8           21          Videoblogging
# 9           22         People & Blogs
# 10          23                 Comedy
# 11          24          Entertainment
# 12          25        News & Politics
# 13          26          Howto & Style
# 14          27              Education
# 15          28   Science & Technology
# 16          29  Nonprofits & Activism
# 17          30                 Movies
# 18          31        Anime/Animation
# 19          32       Action/Adventure
# 20          33               Classics
# 21          34                 Comedy
# 22          35            Documentary
# 23          36                  Drama
# ...

# %%
df.groupby('month').count()
# Out:
#           video_id  trending_date  title  channel_title  category_id  \
# month
# April         4800           4800   4800           4800         4800
# December      6200           6200   6200           6200         6200
# February      5571           5571   5571           5571         5571
# January       5796           5796   5796           5796         5796
# June          2800           2800   2800           2800         2800
# March         6183           6183   6183           6183         6183
# May           6199           6199   6199           6199         6199
# November      3400           3400   3400           3400         3400
#
#           publish_time  tags  views  likes  dislikes  comment_count  \
# month
# April             4800  4800   4800   4800      4800           4800
# December          6200  6200   6200   6200      6200           6200
# February          5571  5571   5571   5571      5571           5571
# ...

# %%
# Aggregate the data according to trending time in calender year and category

# %%
df.groupby('category_id').count()
# Out:
#              video_id  trending_date  title  channel_title  publish_time  \
# category_id
# 1                2345           2345   2345           2345          2345
# 2                 384            384    384            384           384
# 10               6472           6472   6472           6472          6472
# 15                920            920    920            920           920
# 17               2174           2174   2174           2174          2174
# 19                402            402    402            402           402
# 20                817            817    817            817           817
# 22               3210           3210   3210           3210          3210
# 23               3457           3457   3457           3457          3457
# 24               9964           9964   9964           9964          9964
# 25               2487           2487   2487           2487          2487
# 26               4146           4146   4146           4146          4146
# ...

# %%
#join_df = df.merge(df11, left_on='category_id', right_on='category_id')
#join_df = df.join(df11, lsuffix='category_id', rsuffix='category_id')
#df.head()
df12 = df11.astype({'category_id': int})
df12.info()
merged_inner = pd.merge(df, df12, on='category_id')
merged_inner
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
# category_id       32 non-null int64
# category_title    32 non-null object
# dtypes: int64(1), object(1)
# memory usage: 640.0+ bytes
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      0mlNzVSJrT0      17.14.11
# 2      STI2fI7sKMo      17.14.11
# 3      KODzih-pYlU      17.14.11
# 4      8mhTWqWlQzU      17.14.11
# ...            ...           ...
# 40944  V6ElE2xs48c      18.02.06
# 40945  V6ElE2xs48c      18.03.06
# 40946  V6ElE2xs48c      18.04.06
# 40947  V6ElE2xs48c      18.05.06
# 40948  V6ElE2xs48c      18.06.06
#
#                                                    title       channel_title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 1                                   Me-O Cats Commercial             Nobrand
# 2      AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# ...

# %%
df13 = merged_inner.groupby(['month','category_title']).count()
df13
# Out:
#                                video_id  trending_date  title  channel_title  \
# month    category_title
# April    Autos & Vehicles            34             34     34             34
#          Comedy                     407            407    407            407
#          Education                  204            204    204            204
#          Entertainment             1160           1160   1160           1160
#          Film & Animation           264            264    264            264
# ...                                 ...            ...    ...            ...
# November People & Blogs             247            247    247            247
#          Pets & Animals              56             56     56             56
#          Science & Technology       237            237    237            237
#          Sports                     195            195    195            195
#          Travel & Events             25             25     25             25
#
# ...

# %%
df14 = df13.iloc[: , 0:1]
df14
# Out:
#                                video_id
# month    category_title
# April    Autos & Vehicles            34
#          Comedy                     407
#          Education                  204
#          Entertainment             1160
#          Film & Animation           264
# ...                                 ...
# November People & Blogs             247
#          Pets & Animals              56
#          Science & Technology       237
#          Sports                     195
#          Travel & Events             25
#
# [122 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(15,7))
df14.groupby(['month','category_title']).sum()['video_id'].unstack().plot(ax=ax)
ax.set_xlabel('Month')
ax.set_ylabel('Number of videos of particular category')
# Out:
# Text(0, 0.5, 'Number of videos of particular category')
